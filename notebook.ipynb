# %%
from prefect import task, flow

# %%
@task
def formato_tres_cinco_uno():
    print("tarea 1")

@task
def filtarar_solo_us(formato):
    print("tarea 2")

@task
def solo_usd_rv(filtrar):
    print("tarea 3")

@task
def armar_portafolio(rv_usd):
    print("tarea 4")

@task
def compras_y_ventas(armar):
    print("tarea 5")

# %%
@flow
def flujo_de_tareas():
    formato = formato_tres_cinco_uno()
    filtrar = filtarar_solo_us(formato)
    rv_usd = solo_usd_rv(filtrar)
    armar = armar_portafolio(rv_usd)
    compras = compras_y_ventas(armar)

# %%
flujo_de_tareas()
# Out:
# 00:04:42.018 | INFO    | Flow run 'archetypal-kangaroo' - Beginning flow run 'archetypal-kangaroo' for flow 'flujo-de-tareas'
# 00:04:42.025 | INFO    | Flow run 'archetypal-kangaroo' - View at https://app.prefect.cloud/account/0a62f2d0-51cf-45c6-8153-d409f2034a53/workspace/f836f102-f0a4-496b-92d9-abda2d75261a/runs/flow-run/069d44a1-98b9-7aac-8000-353d25d5b746
# tarea 1
# 00:04:42.076 | INFO    | Task run 'formato_tres_cinco_uno-b01' - Finished in state Completed()
# tarea 2
# 00:04:42.082 | INFO    | Task run 'filtarar_solo_us-776' - Finished in state Completed()
# tarea 3
# 00:04:42.087 | INFO    | Task run 'solo_usd_rv-291' - Finished in state Completed()
# tarea 4
# 00:04:42.092 | INFO    | Task run 'armar_portafolio-768' - Finished in state Completed()
# tarea 5
# 00:04:42.098 | INFO    | Task run 'compras_y_ventas-973' - Finished in state Completed()
# 00:04:43.073 | INFO    | Flow run 'archetypal-kangaroo' - Finished in state Completed()
